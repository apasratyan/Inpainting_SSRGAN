# %%
import sys
sys.path.append("./source/")

from pipeline import ssrgan_pipeline

# %%
ssrgan_pipeline(
    dataset_name = "Brain_Tumor_Data_Set",
    dataset_path = "./datasets/Brain_Tumor_Data_Set/images",
    save_path = "./trained_models",
    test_size = 0.5,
    ssrgan_type = "modified",
    mask = "random",
    model_size = 64,
    p = None,
    loss_function = "vgg",
    n_epochs = 100,
    optimizer = "adam",
    initial_lr = 2e-4,
    scheduler_step_size = 25,
    scheduler_gamma = 0.5,
    image_size = 128,
    batch_size = 8,
)
# Out:
# C:\Users\пк\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\пк\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# epoch 1/100
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 282/282 [00:12<00:00, 23.38it/s]
# validation NMSE: 0.054019402139971175
#
# epoch 2/100
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 282/282 [00:12<00:00, 23.48it/s]
# ...
